# %% [markdown]
# # IMDB dataset movie sentiment Analysis - Classification

# %%
# Load the dataset
from tensorflow.keras.datasets import imdb
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words = 10000)

# %%
# see through the data
print(x_train[0])
print(y_train[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]
# 1

# %%
# decode the text
word_index = imdb.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_review = ' '.join([reverse_word_index.get(i - 3, '?') for i in x_train[0]])
print(decoded_review)
# Out:
# ? this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert ? is an amazing actor and now the same being director ? father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for ? and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also ? to the two little boy's that played the ? of norman and paul they were just brilliant children are often left out of the ? list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all

# %%
# prepare the data with multi hot encoding
import numpy as np
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

x_train = vectorize_sequences(x_train)
x_test = vectorize_sequences(x_test)

# %%
print(x_train[0])
# Out:
# [0. 1. 1. ... 0. 0. 0.]

# %%
x_train[0].shape
# Out:
# (10000,)

# %%
x_test[0].shape
# Out:
# (10000,)

# %%
y_train[0]
# Out:
# 1

# %%
#float conversion
y_train = np.asarray(y_train).astype('float32')
y_test = np.asarray(y_test).astype('float32')

# %%
y_train[0]
# Out:
# 1.0

# %% [markdown]
# ## Build the model

# %%
# Model Definition
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# %%
# compiling the model
model.compile(optimizer = 'rmsprop',
              loss = 'binary_crossentropy',
              metrics = ['accuracy'])

# %%
# Setting aside a validation set
x_val = x_train[:1000]
partial_x_train = x_train[1000:]
y_val = y_train[:1000]
partial_y_train = y_train[1000:]

# %%
# train the model
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 20,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.7338 - loss: 0.5603 - val_accuracy: 0.8770 - val_loss: 0.3296
# Epoch 2/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9052 - loss: 0.2844 - val_accuracy: 0.8740 - val_loss: 0.2818
# Epoch 3/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9276 - loss: 0.2159 - val_accuracy: 0.8930 - val_loss: 0.2525
# Epoch 4/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9373 - loss: 0.1798 - val_accuracy: 0.8920 - val_loss: 0.2642
# Epoch 5/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9455 - loss: 0.1578 - val_accuracy: 0.8870 - val_loss: 0.2672
# Epoch 6/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9535 - loss: 0.1348 - val_accuracy: 0.8820 - val_loss: 0.2871
# Epoch 7/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9597 - loss: 0.1223 - val_accuracy: 0.8940 - val_loss: 0.2833
# Epoch 8/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9657 - loss: 0.1073 - val_accuracy: 0.8930 - val_loss: 0.2997
# Epoch 9/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9657 - loss: 0.1041 - val_accuracy: 0.8830 - val_loss: 0.3241
# Epoch 10/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9712 - loss: 0.0918 - val_accuracy: 0.8870 - val_loss: 0.3350
# Epoch 11/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9732 - loss: 0.0842 - val_accuracy: 0.8770 - val_loss: 0.3539
# Epoch 12/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9788 - loss: 0.0717 - val_accuracy: 0.8810 - val_loss: 0.3687
# Epoch 13/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9806 - loss: 0.0669 - val_accuracy: 0.8680 - val_loss: 0.4312
# Epoch 14/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9836 - loss: 0.0597 - val_accuracy: 0.8790 - val_loss: 0.4029
# Epoch 15/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9860 - loss: 0.0526 - val_accuracy: 0.8780 - val_loss: 0.4306
# Epoch 16/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9876 - loss: 0.0473 - val_accuracy: 0.8760 - val_loss: 0.4663
# Epoch 17/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9870 - loss: 0.0449 - val_accuracy: 0.8770 - val_loss: 0.4823
# Epoch 18/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9885 - loss: 0.0418 - val_accuracy: 0.8750 - val_loss: 0.4958
# Epoch 19/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9921 - loss: 0.0344 - val_accuracy: 0.8690 - val_loss: 0.5372
# Epoch 20/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9921 - loss: 0.0312 - val_accuracy: 0.8700 - val_loss: 0.5512

# %%
# plotting the training loss and validation loss
import matplotlib.pyplot as plt
val_loss = history.history['val_loss']
loss = history.history['loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# plot for accuracy
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Retry with a new model

# %%
# Regularization
from tensorflow.keras import models,regularizers

model2 = models.Sequential([
    layers.Dense(16, activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),
    layers.Dense(16, activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),
    layers.Dense(1, activation="sigmoid")
])

# %%
# compiling the model
model2.compile(optimizer = 'rmsprop',
              loss = 'binary_crossentropy',
              metrics = ['accuracy'])

# %%
# train the model
history = model2.fit(partial_x_train,
                    partial_y_train,
                    epochs = 20,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - accuracy: 0.5907 - loss: 0.7030 - val_accuracy: 0.8580 - val_loss: 0.5382
# Epoch 2/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7650 - loss: 0.5559 - val_accuracy: 0.8650 - val_loss: 0.4109
# Epoch 3/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8342 - loss: 0.4471 - val_accuracy: 0.8800 - val_loss: 0.3442
# Epoch 4/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8751 - loss: 0.3885 - val_accuracy: 0.8870 - val_loss: 0.3218
# Epoch 5/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8968 - loss: 0.3451 - val_accuracy: 0.8870 - val_loss: 0.3098
# Epoch 6/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9078 - loss: 0.3161 - val_accuracy: 0.8910 - val_loss: 0.3035
# Epoch 7/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9185 - loss: 0.2826 - val_accuracy: 0.8970 - val_loss: 0.3099
# Epoch 8/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9264 - loss: 0.2693 - val_accuracy: 0.8960 - val_loss: 0.3151
# Epoch 9/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9309 - loss: 0.2598 - val_accuracy: 0.8890 - val_loss: 0.3276
# Epoch 10/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9372 - loss: 0.2457 - val_accuracy: 0.8860 - val_loss: 0.3455
# Epoch 11/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9376 - loss: 0.2351 - val_accuracy: 0.8980 - val_loss: 0.3437
# Epoch 12/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9397 - loss: 0.2350 - val_accuracy: 0.8950 - val_loss: 0.3594
# Epoch 13/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9437 - loss: 0.2295 - val_accuracy: 0.8920 - val_loss: 0.3702
# Epoch 14/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9441 - loss: 0.2233 - val_accuracy: 0.8910 - val_loss: 0.3810
# Epoch 15/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9461 - loss: 0.2186 - val_accuracy: 0.8860 - val_loss: 0.3849
# Epoch 16/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9489 - loss: 0.2130 - val_accuracy: 0.8880 - val_loss: 0.4045
# Epoch 17/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9453 - loss: 0.2244 - val_accuracy: 0.8880 - val_loss: 0.4146
# Epoch 18/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9487 - loss: 0.2092 - val_accuracy: 0.8840 - val_loss: 0.4083
# Epoch 19/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9501 - loss: 0.2101 - val_accuracy: 0.8830 - val_loss: 0.4192
# Epoch 20/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9505 - loss: 0.2132 - val_accuracy: 0.8840 - val_loss: 0.4304

# %%
# plotting the training loss and validation loss
import matplotlib.pyplot as plt
val_loss = history.history['val_loss']
loss = history.history['loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# plot for accuracy
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
